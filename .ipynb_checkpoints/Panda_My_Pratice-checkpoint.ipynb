# %%
import pandas as pd

# %%
series = pd.Series(["Chayan", "Kheya","Roni"])
series
# Out:
# 0    Chayan
# 1     Kheya
# 2      Roni
# dtype: str

# %%
car_data = pd.DataFrame({"Car Make":series,"Colures":"Red"})
car_data
# Out:
#   Car Make Colures
# 0   Chayan     Red
# 1    Kheya     Red
# 2     Roni     Red

# %%
food_database = pd.read_csv("healthy_foods_database.csv")
food_database
# Out:
#                                          food_name food_type  calories  \
# 0                                     Abiyuch, raw    Fruits      69.0
# 1                           Agave, raw (Southwest)     Other      68.0
# 2                            Almond butter, creamy     Other     603.0
# 3                         Amaranth grain, uncooked    Grains     371.0
# 4                                APPLEBEE'S, chili     Other     656.0
# ...                                            ...       ...       ...
# 9023                             BEAN & RICE CHIPS    Grains     500.0
# 9024  BEAN & RICE CHIPS WITH SEA SALT!, BLACK BEAN    Grains     500.0
# 9025                   BEAN & RICE CHIPS, BARBECUE    Grains     500.0
# 9026                 BEAN & RICE CHIPS, BLACK BEAN    Grains     500.0
# 9027                      BEAN & RICE CHIPS, NACHO    Grains     500.0
#
#       protein_g  fat_g  carbs_g  fiber_g  sugar_g  sodium_mg  health_score
# ...

# %%
food_database.head(10)
# Out:
#                                            food_name   food_type  calories  \
# 0                                       Abiyuch, raw      Fruits      69.0
# 1                             Agave, raw (Southwest)       Other      68.0
# 2                              Almond butter, creamy       Other     603.0
# 3                           Amaranth grain, uncooked      Grains     371.0
# 4                                  APPLEBEE'S, chili       Other     656.0
# 5  Apricots, dried, sulfured, stewed, with added ...      Fruits     113.0
# 6                                    Arrowroot flour      Grains     357.0
# 7  Artichokes, (globe or french), cooked, boiled,...  Vegetables      51.0
# 8  Artichokes, (globe or french), cooked, boiled,...  Vegetables      53.0
# 9  Artichokes, (globe or french), frozen, cooked,...  Vegetables     188.0
#
#    protein_g  fat_g  carbs_g  fiber_g  sugar_g  sodium_mg  health_score
# 0       1.50   0.10    17.60     5.30     8.55     20.000            65
# ...

# %%
food_database.tail(10)
# Out:
#                                               food_name food_type  calories  \
# 9018   BEAN & CHEESE TRADITIONAL BURRITO, BEAN & CHEESE     Dairy     227.0
# 9019                                 BEAN & CHEESE WRAP     Dairy     181.0
# 9020                         BEAN & GREEN CHILE BURRITO     Other     190.0
# 9021  BEAN & LENTIL BLEND SPROUTED MUNG BEANS, SPROU...    Grains     364.0
# 9022                   BEAN & RICE BURRITO, BEAN & RICE    Grains     182.0
# 9023                                  BEAN & RICE CHIPS    Grains     500.0
# 9024       BEAN & RICE CHIPS WITH SEA SALT!, BLACK BEAN    Grains     500.0
# 9025                        BEAN & RICE CHIPS, BARBECUE    Grains     500.0
# 9026                      BEAN & RICE CHIPS, BLACK BEAN    Grains     500.0
# 9027                           BEAN & RICE CHIPS, NACHO    Grains     500.0
#
#       protein_g  fat_g  carbs_g  fiber_g  sugar_g  sodium_mg  health_score
# ...

# %%
food_database.dtypes
# Out:
# food_name           str
# food_type           str
# calories        float64
# protein_g       float64
# fat_g           float64
# carbs_g         float64
# fiber_g         float64
# sugar_g         float64
# sodium_mg       float64
# health_score      int64
# dtype: object

# %%
food_database.columns
# Out:
# Index(['food_name', 'food_type', 'calories', 'protein_g', 'fat_g', 'carbs_g',
#        'fiber_g', 'sugar_g', 'sodium_mg', 'health_score'],
#       dtype='str')

# %%
food_database.index
# Out:
# RangeIndex(start=0, stop=9028, step=1)

# %%
food_database.describe()
# Out:
#            calories    protein_g        fat_g      carbs_g      fiber_g  \
# count   9028.000000  9021.000000  9014.000000  9002.000000  8676.000000
# mean     329.047652    15.990428     9.948124    26.990668     4.926060
# std      316.877758     9.395426    13.400124    41.330864     9.373754
# min        0.000000     0.000000     0.000000    -0.705000     0.000000
# 25%      134.000000    10.600000     1.790000     0.000000     0.000000
# 50%      247.000000    14.300000     5.220000    17.900000     3.600000
# 75%      422.000000    20.900000    11.300000    50.000000     7.100000
# max    11800.000000   131.000000   150.000000  2940.000000   588.000000
#
#            sugar_g       sodium_mg  health_score
# count  8027.000000     8956.000000   9028.000000
# mean      3.574429      390.662698     62.167147
# std       6.276089    11438.273033      4.004052
# min       0.000000        0.000000     60.000000
# 25%       0.000000       49.000000     60.000000
# ...

# %%
food_database.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9028 entries, 0 to 9027
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   food_name     9028 non-null   str
#  1   food_type     9028 non-null   str
#  2   calories      9028 non-null   float64
#  3   protein_g     9021 non-null   float64
#  4   fat_g         9014 non-null   float64
#  5   carbs_g       9002 non-null   float64
#  6   fiber_g       8676 non-null   float64
#  7   sugar_g       8027 non-null   float64
#  8   sodium_mg     8956 non-null   float64
#  9   health_score  9028 non-null   int64
# dtypes: float64(7), int64(1), str(2)
# memory usage: 705.4 KB

# %%
food_database["calories"].mean()
# Out:
# np.float64(329.0476517501108)

# %%
food_database["calories"].median()
# Out:
# np.float64(247.0)

# %%
food_database["calories"].max()
# Out:
# np.float64(11800.0)

# %%
food_database["calories"].min()
# Out:
# np.float64(0.0)

# %%
food_database["calories"].std()
# Out:
# np.float64(316.8777583110256)

# %%
food_database["calories"].var()
# Out:
# np.float64(100411.51371222078)

# %%
food_database["protein_g"].plot()
# Out:
# <Axes: >

# %%
food_database["health_score"].hist()
# Out:
# <Axes: >

# %%
len(food_database)
# Out:
# 9028

# %%
ecom_data = pd.read_csv("ecommerce_sales_data.csv")

# %%
ecom_data.head()
# Out:
#    Order Date Product Name     Category Region  Quantity  Sales  Profit
# 0  2024-12-31      Printer       Office  North         4   3640  348.93
# 1  2022-11-27        Mouse  Accessories   East         7   1197  106.53
# 2  2022-05-11       Tablet  Electronics  South         5   5865  502.73
# 3  2024-03-16        Mouse  Accessories  South         2    786  202.87
# 4  2022-09-10        Mouse  Accessories   West         1    509  103.28

# %%
ecom_data.dtypes
# Out:
# Order Date          str
# Product Name        str
# Category            str
# Region              str
# Quantity          int64
# Sales             int64
# Profit          float64
# dtype: object

# %%
ecom_data.columns
# Out:
# Index(['Order Date', 'Product Name', 'Category', 'Region', 'Quantity', 'Sales',
#        'Profit'],
#       dtype='str')

# %%
ecom_data.index
# Out:
# RangeIndex(start=0, stop=3500, step=1)

# %%
ecom_data.describe()
# Out:
#           Quantity         Sales       Profit
# count  3500.000000   3500.000000  3500.000000
# mean      4.931714   3047.966000   527.047203
# std       2.575895   2440.213237   504.139732
# min       1.000000     51.000000     6.970000
# 25%       3.000000   1049.500000   158.695000
# 50%       5.000000   2350.500000   361.070000
# 75%       7.000000   4537.000000   729.125000
# max       9.000000  10782.000000  2946.930000

# %%
ecom_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    3500 non-null   str
#  1   Product Name  3500 non-null   str
#  2   Category      3500 non-null   str
#  3   Region        3500 non-null   str
#  4   Quantity      3500 non-null   int64
#  5   Sales         3500 non-null   int64
#  6   Profit        3500 non-null   float64
# dtypes: float64(1), int64(2), str(4)
# memory usage: 191.5 KB

# %%
ecom_data["Profit"].mean()
# Out:
# np.float64(527.0472028571428)

# %%
ecom_data["Profit"].max()
# Out:
# np.float64(2946.93)

# %%
ecom_data["Profit"].min()
# Out:
# np.float64(6.97)

# %%
ecom_data["Profit"].sum()
# Out:
# np.float64(1844665.21)

# %%
len(ecom_data)
# Out:
# 3500

# %%
ecom_data.loc[10]
# Out:
# Order Date       2023-12-04
# Product Name        Monitor
# Category        Accessories
# Region                South
# Quantity                  6
# Sales                  7074
# Profit              1357.68
# Name: 10, dtype: object

# %%
ecom_data["Product Name"].unique()
# Out:
# <StringArray>
# [   'Printer',      'Mouse',     'Tablet',     'Camera', 'Headphones',
#  'Smartwatch',    'Monitor', 'Smartphone',   'Keyboard',     'Laptop']
# Length: 10, dtype: str

# %%
len(ecom_data[ecom_data["Product Name"]=="Smartphone"])
# Out:
# 330

# %%
ecom_data[ecom_data["Product Name"]=="Monitor"]
# Out:
#       Order Date Product Name     Category Region  Quantity  Sales   Profit
# 10    2023-12-04      Monitor  Accessories  South         6   7074  1357.68
# 42    2022-06-10      Monitor  Accessories   West         3   3018   320.11
# 45    2022-01-27      Monitor  Accessories  South         6   3672  1002.50
# 56    2022-05-30      Monitor  Accessories  South         3   1872   553.10
# 58    2024-09-30      Monitor  Accessories   West         5   5210  1338.80
# ...          ...          ...          ...    ...       ...    ...      ...
# 3440  2023-06-03      Monitor  Accessories  South         5    280    79.77
# 3445  2023-09-03      Monitor  Accessories  South         5   4615   251.00
# 3472  2023-09-13      Monitor  Accessories   East         8   3544   454.14
# 3495  2023-02-15      Monitor  Accessories  North         4   4064   771.16
# 3496  2022-09-18      Monitor  Accessories   East         1   1117   119.89
#
# [364 rows x 7 columns]

# %%
ecom_data["Profit"].plot()
# Out:
# <Axes: >

# %%
ecom_data["Sales"].hist()
# Out:
# <Axes: >

# %%
ecom_data["Profit"].hist()
# Out:
# <Axes: >
