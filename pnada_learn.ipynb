# %%
import pandas as pd

# %%
# 2 main datatpyes

series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: str

# %% [markdown]
# ## SERIES = 1 DIMENSIONLA

# %%
colours = pd.Series(["Red","Blue","White"])

# %%
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: str

# %%
#Dataframe = 2-dimensition here we can use row and colum
car_data = pd.DataFrame({"Car make": series, "Colour ": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW     Red
# 1   Toyota    Blue
# 2    Honda   White

# %%
#import data from google Sheet
car_seles = pd.read_csv("car_sales.csv")

# %%
car_seles
# Out:
#       Make  colour  odometer  Doors                Price
# 0   Toyota     Red    235234      4          $34,345.00
# 1      BMW     Red    234234      3         $345,345.00
# 2   Toyota  Yellow       574      5      $78,678,678.00
# 3    Honda  Yellow        57      4       $5,576,567.00
# 4    Honda  Yellow       764      3       $2,523,525.00
# 5    Honda     Red      3523      5      $23,523,523.00
# 6   Toyota   White        23      5   $2,523,525,235.00
# 7      BMW   White       423      4         $234,234.00
# 8      BMW   White        42      5          $23,462.00
# 9      BMW   White        34      3      $24,523,523.00
# 10  Nissan   Black         6      6         $245,235.00
# 11  Toyota   Black       523      4         $345,235.00
# 12     BMW   Black      4234      3          $35,234.00

# %%
# Exportating  a datafream
car_seles.to_csv("Update_car_seles.csv", index=False)

# %%
update_car = pd.read_csv("Update_car_seles.csv")

# %%
update_car
# Out:
#       Make  colour  odometer  Doors                Price
# 0   Toyota     Red    235234      4          $34,345.00
# 1      BMW     Red    234234      3         $345,345.00
# 2   Toyota  Yellow       574      5      $78,678,678.00
# 3    Honda  Yellow        57      4       $5,576,567.00
# 4    Honda  Yellow       764      3       $2,523,525.00
# 5    Honda     Red      3523      5      $23,523,523.00
# 6   Toyota   White        23      5   $2,523,525,235.00
# 7      BMW   White       423      4         $234,234.00
# 8      BMW   White        42      5          $23,462.00
# 9      BMW   White        34      3      $24,523,523.00
# 10  Nissan   Black         6      6         $245,235.00
# 11  Toyota   Black       523      4         $345,235.00
# 12     BMW   Black      4234      3          $35,234.00

# %% [markdown]
# ## Describe Data

# %%
#Attribute
car_seles.dtypes 

#Function
#car_seles.to_csv()
# Out:
# Make          str
# colour        str
# odometer    int64
# Doors       int64
# Price         str
# dtype: object

# %%
car_seles.columns
# Out:
# Index(['Make', 'colour', 'odometer', 'Doors', 'Price'], dtype='str')

# %%
car_seles.index
# Out:
# RangeIndex(start=0, stop=13, step=1)

# %%
car_seles.describe()
# Out:
#             odometer      Doors
# count      13.000000  13.000000
# mean    36897.769231   4.153846
# std     87813.022144   0.987096
# min         6.000000   3.000000
# 25%        42.000000   3.000000
# 50%       523.000000   4.000000
# 75%      3523.000000   5.000000
# max    235234.000000   6.000000

# %%
car_seles.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      13 non-null     str
#  1   colour    13 non-null     str
#  2   odometer  13 non-null     int64
#  3   Doors     13 non-null     int64
#  4   Price     13 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 652.0 bytes

# %%
car_seles
# Out:
#       Make  colour  odometer  Doors                Price
# 0   Toyota     Red    235234      4          $34,345.00
# 1      BMW     Red    234234      3         $345,345.00
# 2   Toyota  Yellow       574      5      $78,678,678.00
# 3    Honda  Yellow        57      4       $5,576,567.00
# 4    Honda  Yellow       764      3       $2,523,525.00
# 5    Honda     Red      3523      5      $23,523,523.00
# 6   Toyota   White        23      5   $2,523,525,235.00
# 7      BMW   White       423      4         $234,234.00
# 8      BMW   White        42      5          $23,462.00
# 9      BMW   White        34      3      $24,523,523.00
# 10  Nissan   Black         6      6         $245,235.00
# 11  Toyota   Black       523      4         $345,235.00
# 12     BMW   Black      4234      3          $35,234.00

# %%
car_price = pd.Series([3000,1600,2000])

# %%
car_price.mean()
# Out:
# np.float64(2200.0)

# %%
car_seles.sum()
# Out:
# Make        ToyotaBMWToyotaHondaHondaHondaToyotaBMWBMWBMWN...
# colour      RedRedYellowYellowYellowRedWhiteWhiteWhiteWhit...
# odometer                                               479671
# Doors                                                      54
# Price        $34,345.00  $345,345.00  $78,678,678.00  $5,5...
# dtype: object

# %%
car_seles["Doors"].sum()
# Out:
# np.int64(54)

# %%
car_seles["Doors"].mean()
# Out:
# np.float64(4.153846153846154)

# %%
car_seles["Doors"].median()
# Out:
# np.float64(4.0)

# %%
len(car_seles)
# Out:
# 13

# %% [markdown]
# ## Viewing and selecting Data

# %%
car_seles.head()
# Out:
#      Make  colour  odometer  Doors             Price
# 0  Toyota     Red    235234      4       $34,345.00
# 1     BMW     Red    234234      3      $345,345.00
# 2  Toyota  Yellow       574      5   $78,678,678.00
# 3   Honda  Yellow        57      4    $5,576,567.00
# 4   Honda  Yellow       764      3    $2,523,525.00

# %%
car_seles.head(10)
# Out:
#      Make  colour  odometer  Doors                Price
# 0  Toyota     Red    235234      4          $34,345.00
# 1     BMW     Red    234234      3         $345,345.00
# 2  Toyota  Yellow       574      5      $78,678,678.00
# 3   Honda  Yellow        57      4       $5,576,567.00
# 4   Honda  Yellow       764      3       $2,523,525.00
# 5   Honda     Red      3523      5      $23,523,523.00
# 6  Toyota   White        23      5   $2,523,525,235.00
# 7     BMW   White       423      4         $234,234.00
# 8     BMW   White        42      5          $23,462.00
# 9     BMW   White        34      3      $24,523,523.00

# %%
car_seles.tail()
# Out:
#       Make colour  odometer  Doors             Price
# 8      BMW  White        42      5       $23,462.00
# 9      BMW  White        34      3   $24,523,523.00
# 10  Nissan  Black         6      6      $245,235.00
# 11  Toyota  Black       523      4      $345,235.00
# 12     BMW  Black      4234      3       $35,234.00

# %%
car_seles.tail(10)
# Out:
#       Make  colour  odometer  Doors                Price
# 3    Honda  Yellow        57      4       $5,576,567.00
# 4    Honda  Yellow       764      3       $2,523,525.00
# 5    Honda     Red      3523      5      $23,523,523.00
# 6   Toyota   White        23      5   $2,523,525,235.00
# 7      BMW   White       423      4         $234,234.00
# 8      BMW   White        42      5          $23,462.00
# 9      BMW   White        34      3      $24,523,523.00
# 10  Nissan   Black         6      6         $245,235.00
# 11  Toyota   Black       523      4         $345,235.00
# 12     BMW   Black      4234      3          $35,234.00

# %%
# .loc and .iloc
animals = pd.Series(["Cat","Dog","bird","panda","Snake"])
animals
# Out:
# 0      Cat
# 1      Dog
# 2     bird
# 3    panda
# 4    Snake
# dtype: str

# %%
animals = pd.Series(["Cat","Dog","bird","panda","Snake"],index=[0,3,8,3,6])
animals
# Out:
# 0      Cat
# 3      Dog
# 8     bird
# 3    panda
# 6    Snake
# dtype: str

# %%
# .loc Index Location Value
animals.loc[3]
# Out:
# 3      Dog
# 3    panda
# dtype: str

# %%
animals.loc[6]
# Out:
# 'Snake'

# %%
car_seles.loc[5]
# Out:
# Make                   Honda
# colour                   Red
# odometer                3523
# Doors                      5
# Price        $23,523,523.00
# Name: 5, dtype: object

# %%
animals
# Out:
# 0      Cat
# 3      Dog
# 8     bird
# 3    panda
# 6    Snake
# dtype: str

# %%
# .iloc it Refers to position
animals.iloc[4]
# Out:
# 'Snake'

# %%
animals
# Out:
# 0      Cat
# 3      Dog
# 8     bird
# 3    panda
# 6    Snake
# dtype: str

# %%
# Slising
animals.iloc[:3]
# Out:
# 0     Cat
# 3     Dog
# 8    bird
# dtype: str

# %%
car_seles.loc[:3]
# Out:
#      Make  colour  odometer  Doors             Price
# 0  Toyota     Red    235234      4       $34,345.00
# 1     BMW     Red    234234      3      $345,345.00
# 2  Toyota  Yellow       574      5   $78,678,678.00
# 3   Honda  Yellow        57      4    $5,576,567.00

# %%
car_seles["Make"]
# Out:
# 0     Toyota
# 1        BMW
# 2     Toyota
# 3      Honda
# 4      Honda
# 5      Honda
# 6     Toyota
# 7        BMW
# 8        BMW
# 9        BMW
# 10    Nissan
# 11    Toyota
# 12       BMW
# Name: Make, dtype: str

# %%
car_seles.Make
# Out:
# 0     Toyota
# 1        BMW
# 2     Toyota
# 3      Honda
# 4      Honda
# 5      Honda
# 6     Toyota
# 7        BMW
# 8        BMW
# 9        BMW
# 10    Nissan
# 11    Toyota
# 12       BMW
# Name: Make, dtype: str

# %%
car_seles["Doors"]
# Out:
# 0     4
# 1     3
# 2     5
# 3     4
# 4     3
# 5     5
# 6     5
# 7     4
# 8     5
# 9     3
# 10    6
# 11    4
# 12    3
# Name: Doors, dtype: int64

# %%
car_seles[car_seles["Make"]=="Toyota"]
# Out:
#       Make  colour  odometer  Doors                Price
# 0   Toyota     Red    235234      4          $34,345.00
# 2   Toyota  Yellow       574      5      $78,678,678.00
# 6   Toyota   White        23      5   $2,523,525,235.00
# 11  Toyota   Black       523      4         $345,235.00

# %%
car_seles[car_seles["odometer"]>600]
# Out:
#       Make  colour  odometer  Doors             Price
# 0   Toyota     Red    235234      4       $34,345.00
# 1      BMW     Red    234234      3      $345,345.00
# 4    Honda  Yellow       764      3    $2,523,525.00
# 5    Honda     Red      3523      5   $23,523,523.00
# 12     BMW   Black      4234      3       $35,234.00

# %%
pd.crosstab(car_seles["Make"],car_seles["Doors"])
# Out:
# Doors   3  4  5  6
# Make
# BMW     3  1  1  0
# Honda   1  1  1  0
# Nissan  0  0  0  1
# Toyota  0  2  2  0

# %%
#Groupby
car_seles.groupby("Make")["odometer"].mean()
# Out:
# Make
# BMW       47793.4
# Honda      1448.0
# Nissan        6.0
# Toyota    59088.5
# Name: odometer, dtype: float64

# %%
car_seles["Doors"].plot()
# Out:
# <Axes: >

# %%
car_seles["odometer"].hist()
# Out:
# <Axes: >

# %%
car_seles
# Out:
#       Make  colour  odometer  Doors                Price
# 0   Toyota     Red    235234      4          $34,345.00
# 1      BMW     Red    234234      3         $345,345.00
# 2   Toyota  Yellow       574      5      $78,678,678.00
# 3    Honda  Yellow        57      4       $5,576,567.00
# 4    Honda  Yellow       764      3       $2,523,525.00
# 5    Honda     Red      3523      5      $23,523,523.00
# 6   Toyota   White        23      5   $2,523,525,235.00
# 7      BMW   White       423      4         $234,234.00
# 8      BMW   White        42      5          $23,462.00
# 9      BMW   White        34      3      $24,523,523.00
# 10  Nissan   Black         6      6         $245,235.00
# 11  Toyota   Black       523      4         $345,235.00
# 12     BMW   Black      4234      3          $35,234.00

# %%
car_seles["Price"] = (
    car_seles["Price"]
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
    .str.replace(".00", "", regex=False)
    .str.strip()
    .astype(int)
)

# %%
car_seles.dtypes
# Out:
# Make          str
# colour        str
# odometer    int64
# Doors       int64
# Price       int64
# dtype: object

# %%
car_seles
# Out:
#       Make  colour  odometer  Doors       Price
# 0   Toyota     Red    235234      4       34345
# 1      BMW     Red    234234      3      345345
# 2   Toyota  Yellow       574      5    78678678
# 3    Honda  Yellow        57      4     5576567
# 4    Honda  Yellow       764      3     2523525
# 5    Honda     Red      3523      5    23523523
# 6   Toyota   White        23      5  2523525235
# 7      BMW   White       423      4      234234
# 8      BMW   White        42      5       23462
# 9      BMW   White        34      3    24523523
# 10  Nissan   Black         6      6      245235
# 11  Toyota   Black       523      4      345235
# 12     BMW   Black      4234      3       35234

# %%
car_seles["Price"].plot()
# Out:
# <Axes: >
